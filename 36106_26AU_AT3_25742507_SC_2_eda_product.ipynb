# %% [markdown]
# # **EDA Notebook**

# %% [markdown]
# ---
# ## 0. Setup Environment

# %%
# DO NOT MODIFY THE CODE IN THIS CELL
# !pip install -q utstd

from utstd.folders import *
from utstd.ipyrenders import *

at = AtFolder(
    course_code=36106,
    assignment="AT3",
)
at.run()

import warnings
warnings.simplefilter(action='ignore')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 50.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 49.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# hdbscan 0.8.42 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# umap-learn 0.5.12 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Mounted at /content/gdrive
#
# You can now save your data files in: /content/gdrive/MyDrive/36106/assignment/AT3/data

# %% [markdown]
# ---
# ## Student Information

# %%
group_name = "Group 11"
student_name = "Rose Marie Tazbaz"
student_id = "25742507"

# %%
# Do not modify this code
print_tile(size="h1", key='group_name', value=group_name)
# Out:
# <p style="color:grey">group_name</p><h1 font-size: 3em>Group 11</h1>

# %%
# Do not modify this code
print_tile(size="h1", key='student_name', value=student_name)
# Out:
# <p style="color:grey">student_name</p><h1 font-size: 3em>Rose Marie Tazbaz</h1>

# %%
# Do not modify this code
print_tile(size="h1", key='student_id', value=student_id)
# Out:
# <p style="color:grey">student_id</p><h1 font-size: 3em>25742507</h1>

# %% [markdown]
# ---
# ## 0. Python Packages

# %% [markdown]
# ### 0.a Install Additional Packages
#
# > If you are using additional packages, you need to install them here using the command: `! pip install <package_name>`

# %%
# <Student to fill this section>

# %% [markdown]
# ### 0.b Import Packages

# %%
import pandas as pd
import altair as alt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
# ## B. Data Understanding

# %%
# Do not modify this code
try:
  df = pd.read_csv(at.folder_path / "product.csv")
except Exception as e:
  print(e)

# %% [markdown]
# ### B.1 Explore Dataset

# %%
print("shape:", df.shape)
df.head()
# Out:
# shape: (886, 23)
#                              product_id  is_manufactured  is_sellable  \
# 0  776904bb-c44c-46c4-9f48-84aa4f194272              0.0          0.0
# 1  9cfd0ae7-9945-4823-8f73-c26581afae87              0.0          0.0
# 2  e7f9c66f-61d6-46af-b105-b2c6d95bdc09              1.0          1.0
# 3  e6f3e1fb-8250-487d-b38c-df7d6a3cdbeb              1.0          1.0
# 4  bc67ce0d-72d6-4026-a2ca-fefc88073e50              1.0          1.0
#
#    safety_stock_level  reorder_point  days_to_manufacture  \
# 0              1000.0          750.0                  0.0
# 1              1000.0          750.0                  0.0
# 2               100.0           75.0                  4.0
# 3               500.0          375.0                  1.0
# 4               100.0           75.0                  4.0
#
#                  product_subcategory_id  product_model_id  \
# 0                                   NaN               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886 entries, 0 to 885
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   product_id                886 non-null    object
#  1   is_manufactured           886 non-null    float64
#  2   is_sellable               886 non-null    float64
#  3   safety_stock_level        886 non-null    float64
#  4   reorder_point             886 non-null    float64
#  5   days_to_manufacture       886 non-null    float64
#  6   product_subcategory_id    530 non-null    object
#  7   product_model_id          530 non-null    float64
#  8   name                      637 non-null    object
#  9   product_number            782 non-null    object
#  10  color                     461 non-null    object
#  11  standard_cost             754 non-null    float64
#  12  list_price                886 non-null    float64
# ...

# %%
df.describe(include='all')
# Out:
#                                   product_id  is_manufactured  is_sellable  \
# count                                    886       886.000000   886.000000
# unique                                   504              NaN          NaN
# top     3615d396-f30f-4805-b326-de5b780a5507              NaN          NaN
# freq                                       6              NaN          NaN
# mean                                     NaN         0.506772     0.598194
# std                                      NaN         0.500237     0.490540
# min                                      NaN         0.000000     0.000000
# 25%                                      NaN         0.000000     0.000000
# 50%                                      NaN         1.000000     1.000000
# 75%                                      NaN         1.000000     1.000000
# max                                      NaN         1.000000     1.000000
#
#         safety_stock_level  reorder_point  days_to_manufacture  \
# ...

# %%
df.isnull().sum()
# Out:
# product_id                    0
# is_manufactured               0
# is_sellable                   0
# safety_stock_level            0
# reorder_point                 0
# days_to_manufacture           0
# product_subcategory_id      356
# product_model_id            356
# name                        249
# product_number              104
# color                       425
# standard_cost               132
# list_price                    0
# size                        508
# size_unit_measure_code      565
# weight_unit_measure_code    510
# weight                      510
# product_line                389
# class                       433
# style                       505
# sell_start_date               0
# sell_end_date               720
# discontinued_date           886
# dtype: int64

# %%
dataset_insights = "The product table consists of 886 observations and 23 columns. It describes such aspects about products as their characteristics, inventory management, production characteristics, pricing and product lifecycle. The current product dataset consists of categorical and numeric variables, which provide us with a wide array of information needed for analysing sales behaviour of the products and helping in finding anomalies. There are a number of features with high percentage of missing values, specifically such features related to the characteristics of products like size, weight, style, class and product_subcategory_id. Moreover, there is a discontinued_date variable, which has 100% missing values, implying that at the moment there is no information on any products that have been discontinued. Missing values might be associated with differences between different kinds of products, lack of information or products that do not need such attributes. As regards using the product dataset for machine learning purposes, we can say that there are a number of columns that could help in detecting anomalies in purchases – these are pricing variables (list_price, standard_cost), inventory variables (safety_stock_level, reorder_point) and manufacturing features (days_to_manufacture, is_manufactured)."

# %%
# Do not modify this code
print_tile(size="h3", key='dataset_insights', value=dataset_insights)
# Out:
# <p style="color:grey">dataset_insights</p><h3 font-size: 3em>The product dataset contains 886 records and 23 features describing product characteristics, inventory management information, manufacturing attributes, pricing variables, and product lifecycle data. The dataset includes both numerical and categorical variables, providing a rich source of information for analysing product-related sales behaviour and supporting anomaly detection tasks. Several features exhibit substantial missing values, particularly those related to product attributes such as size, weight, style, class, and product_subcategory_id. Additionally, the discontinued_date feature contains 100% missing values, indicating that no discontinued products are currently recorded in the dataset. These missing values may reflect differences between product types, incomplete product specifications, or products that do not require certain attributes. From a machine learning perspective, the dataset contains multiple feature
# ...

# %% [markdown]
# ### B.2 Explore Feature of Interest `list_price`

# %%
df['list_price'].describe()
# Out:
# count     886.000000
# mean      448.014424
# std       761.953043
# min         0.000000
# 25%         0.000000
# 50%        53.990000
# 75%       594.830000
# max      3578.270000
# Name: list_price, dtype: float64

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    df['list_price'],
    bins=30,
    kde=True
)

plt.title('Distribution of product list Prices')
plt.xlabel('List Price')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(10,4))

sns.boxplot(
    x=df['list_price']
)

plt.title('Boxplot of product list Prices')

plt.show()

# %%
feature_1_insights = "The list_price feature shows a strongly right-skewed distribution, with most products having low prices and a small number of products displaying extremely high prices. Several significant outliers were identified, including products priced above 3500, which may represent premium or specialised items. Additionally, at least 25% of products have a list price of zero, potentially indicating non-sellable items, promotional products, or data quality issues. From a machine learning perspective, the presence of skewness and extreme outliers suggests that robust preprocessing and scaling techniques are necessary before modelling. The feature is highly relevant for anomaly detection because unusual product prices may help identify abnormal sales behaviour or suspicious transactions. However, high-priced products are not inherently anomalous and require contextual information such as product category and purchasing patterns for accurate interpretation."

# %%
# Do not modify this code
print_tile(size="h3", key='feature_1_insights', value=feature_1_insights)
# Out:
# <p style="color:grey">feature_1_insights</p><h3 font-size: 3em>The list_price feature exhibits a highly right-skewed distribution, with most products concentrated at lower price ranges and a small number of products displaying extremely high prices. This is reflected in the substantial difference between the median price (53.99) and the mean price (448.01), indicating the presence of significant positive skewness and high-value outliers within the dataset. The boxplot further confirms the existence of several extreme price outliers, with some products exceeding a list price of 3500. These products may represent premium or specialised items; however, they are particularly relevant within the context of anomaly detection because transactions involving unusually expensive products could potentially be flagged as abnormal purchasing behaviour. An additional observation is that at least 25% of products have a list price equal to zero. This may indicate non-sellable products, internal comp
# ...

# %% [markdown]
# ### B.3 Explore Feature of Interest `standard_cost`

# %%
df['standard_cost'].describe()
# Out:
# count     754.000000
# mean      277.389593
# std       477.725891
# min         0.000000
# 25%         0.000000
# 50%        24.745900
# 75%       352.139400
# max      2171.294200
# Name: standard_cost, dtype: float64

# %%
missing_standard_cost = df['standard_cost'].isnull().sum()

print("Missing values in standard_cost:", missing_standard_cost)
# Out:
# Missing values in standard_cost: 132

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    df['standard_cost'].dropna(),
    bins=30,
    kde=True
)

plt.title('Distribution of Standard Cost')
plt.xlabel('Standard Cost')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(10,4))

sns.boxplot(
    x=df['standard_cost'].dropna()
)

plt.title('Boxplot of Standard Cost')

plt.show()

# %%
feature_2_insights = "The standard_cost feature exhibits a highly right-skewed distribution, with most products concentrated at relatively low cost values and a small number of products displaying extremely high manufacturing or acquisition costs. This pattern is reflected in the substantial difference between the median cost (24.75) and the mean cost (277.39), indicating strong positive skewness and the presence of significant outliers. The boxplot confirms the existence of multiple extreme cost outliers, with some products exceeding a standard cost of 2000. These high-cost products may represent premium or specialised items and are particularly relevant for anomaly detection, as transactions involving unusually expensive products may appear abnormal compared to typical purchasing behaviour. Another important observation is that at least 25% of products have a standard cost equal to zero. This may indicate non-manufactured items, promotional products, bundled components, incomplete costing records, or potential data quality issues. Such values could distort financial analyses and anomaly detection results if not properly handled during preprocessing. Additionally, the feature contains 132 missing values, representing approximately 15% of the dataset. Missing cost information may reduce the reliability of profitability and pricing analyses and will require appropriate handling before model training. The missing values may also suggest inconsistencies in product management processes or differences between product categories. From a machine learning perspective, the strong skewness, presence of extreme outliers, and missing values indicate that preprocessing techniques such as imputation, scaling, and robust outlier handling may be necessary. The standard_cost feature is expected to play an important role in identifying unusual pricing relationships, abnormal margins, and potentially suspicious sales transactions. One limitation of this feature is that high-cost products are not inherently anomalous. Therefore, additional contextual variables such as product category, sales quantity, discounts, and customer purchasing patterns will likely be required to accurately distinguish legitimate premium transactions from genuinely abnormal sales activity."

# %%
# Do not modify this code
print_tile(size="h3", key='feature_2_insights', value=feature_2_insights)
# Out:
# <p style="color:grey">feature_2_insights</p><h3 font-size: 3em>The standard_cost feature exhibits a highly right-skewed distribution, with most products concentrated at relatively low cost values and a small number of products displaying extremely high manufacturing or acquisition costs. This pattern is reflected in the substantial difference between the median cost (24.75) and the mean cost (277.39), indicating strong positive skewness and the presence of significant outliers. The boxplot confirms the existence of multiple extreme cost outliers, with some products exceeding a standard cost of 2000. These high-cost products may represent premium or specialised items and are particularly relevant for anomaly detection, as transactions involving unusually expensive products may appear abnormal compared to typical purchasing behaviour. Another important observation is that at least 25% of products have a standard cost equal to zero. This may indicate non-manufactured items, promotional 
# ...

# %% [markdown]
# ### B.4 Explore Feature of Interest `is_sellable`

# %%
sellable_counts = df['is_sellable'].value_counts()
print(sellable_counts)
# Out:
# is_sellable
# 1.0    530
# 0.0    356
# Name: count, dtype: int64

# %%
sellable_percentage = (df['is_sellable'].value_counts(normalize=True)*100)
print(sellable_percentage)
# Out:
# is_sellable
# 1.0    59.819413
# 0.0    40.180587
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,5))
sns.countplot(x=df['is_sellable'])
plt.title('Dist. of sellable products')
plt.xlabel('Is sellable')
plt.ylabel('Count')
plt.show()

# %%
feature_3_insights = "The is_sellable feature indicates whether a product is available for commercial sale and reveals a mixed distribution within the dataset. Approximately 59.82% of products are classified as sellable, while 40.18% are marked as non-sellable. This suggests that the dataset includes both customer-facing products and internal, administrative, or non-commercial items. From a business perspective, the presence of a substantial proportion of non-sellable products is important because these items may represent components, spare parts, manufacturing materials, or products not intended for direct customer transactions. Within the context of anomaly detection, this feature may provide valuable insights when analysing sales orders. Transactions involving non-sellable products could potentially indicate operational errors, inventory inconsistencies, incorrect product configurations, or suspicious transactional behaviour. As a result, the is_sellable variable may contribute useful contextual information for identifying unusual sales patterns. The feature contains no missing values and demonstrates a relatively balanced distribution compared to many binary categorical variables, making it suitable for machine learning preprocessing and analysis. One limitation of this feature is that non-sellable products are not inherently anomalous, as they may legitimately exist within internal operational systems. Therefore, additional contextual variables such as transaction type, customer behaviour, pricing information, and order details will likely be required to determine whether transactions involving non-sellable products represent genuine anomalies."

# %%
# Do not modify this code
print_tile(size="h3", key='feature_3_insights', value=feature_3_insights)
# Out:
# <p style="color:grey">feature_3_insights</p><h3 font-size: 3em>The is_sellable feature indicates whether a product is available for commercial sale and reveals a mixed distribution within the dataset. Approximately 59.82% of products are classified as sellable, while 40.18% are marked as non-sellable. This suggests that the dataset includes both customer-facing products and internal, administrative, or non-commercial items. From a business perspective, the presence of a substantial proportion of non-sellable products is important because these items may represent components, spare parts, manufacturing materials, or products not intended for direct customer transactions. Within the context of anomaly detection, this feature may provide valuable insights when analysing sales orders. Transactions involving non-sellable products could potentially indicate operational errors, inventory inconsistencies, incorrect product configurations, or suspicious transactional behaviour. As a result, t
# ...

# %% [markdown]
# ### B.5 Explore Feature of Interest `is_manufactured`

# %%
manufactured_counts = df['is_manufactured'].value_counts()
print(manufactured_counts)
# Out:
# is_manufactured
# 1.0    449
# 0.0    437
# Name: count, dtype: int64

# %%
manufactured_percentage = (
    df['is_manufactured'].value_counts(normalize=True) * 100
)

print(manufactured_percentage)
# Out:
# is_manufactured
# 1.0    50.677201
# 0.0    49.322799
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,5))

sns.countplot(
    x=df['is_manufactured']
)

plt.title('Dist. of manufactured products')
plt.xlabel('Is manufactured')
plt.ylabel('Count')

plt.show()

# %%
feature_4_insights = "The is_manufactured feature shows a balanced distribution, with approximately half of the products classified as manufactured and the other half as non-manufactured. This suggests a diverse mix of internally produced and externally sourced products. The feature may provide useful context for anomaly detection, as unusual pricing, costs, or order quantities involving non-manufactured products could indicate operational inconsistencies or suspicious activity. From a machine learning perspective, the balanced distribution is beneficial because it reduces category imbalance and supports more reliable pattern analysis. However, manufacturing status alone is unlikely to identify anomalies without being combined with other variables such as product cost, pricing, and transactional data."

# %%
# Do not modify this code
print_tile(size="h3", key='feature_4_insights', value=feature_4_insights)
# Out:
# <p style="color:grey">feature_4_insights</p><h3 font-size: 3em>The is_manufactured feature indicates whether a product is internally manufactured and shows a highly balanced distribution within the dataset. Approximately 50.68% of products are classified as manufactured, while 49.32% are non-manufactured. This balanced structure suggests that the dataset contains a diverse mix of internally produced and externally sourced products. From a business perspective, manufactured and non-manufactured products may exhibit different operational characteristics, including variations in production costs, inventory management processes, lead times, and pricing structures. These differences may influence transactional behaviour and purchasing patterns across the business. Within the context of anomaly detection, the feature may provide useful contextual information when analysing unusual sales orders or pricing behaviour. For example, transactions involving non-manufactured products with unexpect
# ...

# %% [markdown]
# ### B.6 Explore Feature of Interest `days_to_manufacture`

# %%
df['days_to_manufacture'].describe()
# Out:
# count    886.000000
# mean       1.128668
# std        1.475729
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: days_to_manufacture, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df['days_to_manufacture'],
    bins=10,
    kde=False
)

plt.title('Distribution of Days to Manufacture')
plt.xlabel('Days to Manufacture')
plt.ylabel('Frequency')

plt.show()

# %%
manufacture_days_counts = df['days_to_manufacture'].value_counts().sort_index()

print(manufacture_days_counts)
# Out:
# days_to_manufacture
# 0.0    407
# 1.0    296
# 2.0     14
# 4.0    169
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,3))

sns.boxplot(
    x=df['days_to_manufacture']
)

plt.title('Boxplot of Days to Manufacture')

plt.show()

# %%
feature_5_insights = "The days_to_manufacture feature shows a concentrated distribution, with most products requiring 0 or 1 day to manufacture, suggesting that many products are operationally simple or quickly produced. A smaller group of products requires 4 days, indicating more complex or specialised items that may influence pricing and transactional behaviour. Products requiring 2 days are relatively rare and may represent niche categories. From an anomaly detection perspective, the feature may help identify unusual purchasing patterns when combined with variables such as price, quantity, and customer behaviour. However, longer manufacturing times do not necessarily indicate anomalies, as they may reflect legitimate premium or specialised products."

# %%
# Do not modify this code
print_tile(size="h3", key='feature_5_insights', value=feature_5_insights)
# Out:
# <p style="color:grey">feature_5_insights</p><h3 font-size: 3em>The days_to_manufacture feature represents the number of days required to manufacture each product and exhibits a highly concentrated and segmented distribution. Most products require either 0 or 1 day to manufacture, accounting for the majority of observations within the dataset. This suggests that a large proportion of products are either quickly produced, operationally simple, or potentially sourced without substantial manufacturing requirements. A distinct group of 169 products requires 4 days to manufacture, indicating the existence of a separate category of more complex or resource-intensive products. These products may involve specialised manufacturing processes, premium materials, or more advanced production requirements, which could influence pricing, inventory behaviour, and transactional patterns. An additional observation is that only 14 products require exactly 2 days to manufacture, making this category rela
# ...

# %% [markdown]
# ### B.7 Explore Feature of Interest `product_line`

# %%
product_line_counts = df['product_line'].value_counts()
print(product_line_counts)
# Out:
# product_line
# R    190
# M    162
# T     91
# S     54
# Name: count, dtype: int64

# %%
product_line_percentage = (
    df['product_line'].value_counts(normalize=True) * 100
)

print(product_line_percentage)
# Out:
# product_line
# R    38.229376
# M    32.595573
# T    18.309859
# S    10.865191
# Name: proportion, dtype: float64

# %%
missing_product_line = df['product_line'].isnull().sum()

print("Missing values:", missing_product_line)
# Out:
# Missing values: 389

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x=df['product_line'],
    order=df['product_line'].value_counts().index
)

plt.title('Distribution of Product Lines')
plt.xlabel('Product Line')
plt.ylabel('Count')

plt.show()

# %%
feature_6_insights = "The product_line feature segregates products according to their associated business lines and demonstrates an imbalanced distribution since product line R and product line M are the most common business lines. This implies that certain product lines are highly prevalent in the sales activity process and might create distinct buying behaviors and anomaly boundaries. The feature also possesses many missing values and this might imply incomplete categorizations or internally used products. In terms of anomaly detection, product_line is an important feature because different prices, sales rates, and customer behaviors may exist between the different product categories."

# %%
# Do not modify this code
print_tile(size="h3", key='feature_6_insights', value=feature_6_insights)
# Out:
# <p style="color:grey">feature_6_insights</p><h3 font-size: 3em>The product_line feature categorises products into different business product lines and exhibits an uneven distribution across the dataset. Product lines R and M represent the largest groups, accounting for approximately 38.23% and 32.60% of classified products respectively, while product line S represents the smallest category with only 10.87% of observations. This imbalance suggests that certain product categories dominate the retailer’s product portfolio and may naturally generate higher transaction volumes and more diverse purchasing behaviour. As a result, transactional patterns and anomaly thresholds may vary significantly between product lines. A major observation is the presence of 389 missing values, representing a substantial proportion of the dataset. These missing classifications may indicate products without assigned product lines, internal-use items, incomplete records, or inconsistencies in product categori
# ...

# %% [markdown]
# ### B.8 Explore Feature of Interest `weight`

# %%
df['weight'].describe()
# Out:
# count     376.000000
# mean       76.702872
# std       188.620208
# min         2.120000
# 25%         2.880000
# 50%        17.350000
# 75%        27.350000
# max      1050.000000
# Name: weight, dtype: float64

# %%
missing_weight = df['weight'].isnull().sum()
print("Missing values:", missing_weight)
# Out:
# Missing values: 510

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    df['weight'].dropna(),
    bins=30,
    kde=True
)

plt.title('Distribution of Product Weight')
plt.xlabel('Weight')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(10,4))

sns.boxplot(
    x=df['weight'].dropna()
)

plt.title('Boxplot of Product Weight')

plt.show()

# %%
feature_7_insights = "The weight attribute has a highly skewed right distribution, where many products have low weights, but some have extremely high weights. There were several extreme outliers, where some products have more than 1000 units of weight, and this might be an indication that these are some special items which have special operations. This particular attribute would be useful for identifying anomalies since some special products may have strange purchase behavior. But the attribute has many missing values, which indicates that we need to do some preprocessing on the attribute."

# %%
# Do not modify this code
print_tile(size="h3", key='feature_7_insights', value=feature_7_insights)
# Out:
# <p style="color:grey">feature_7_insights</p><h3 font-size: 3em>The weight feature exhibits a highly right-skewed distribution, with most products concentrated at relatively low weight values and a small number of products displaying extremely high weights. This pattern is reflected in the substantial difference between the median weight (17.35) and the mean weight (76.70), indicating strong positive skewness and the presence of significant outliers. The boxplot confirms the existence of multiple extreme weight outliers, with some products exceeding a weight of 1000 units. These unusually heavy products may represent specialised equipment, bulk products, or operationally complex items. From a business perspective, such products may influence shipping costs, freight charges, storage requirements, and overall transaction values. Within the context of anomaly detection, product weight may provide valuable contextual information because unusually heavy products could naturally generate ab
# ...
